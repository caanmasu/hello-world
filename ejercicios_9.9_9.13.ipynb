# %%
#Ejercicio 9.9
n = 3
det = 1.0
M = []
for z in range(n):
    M.append([0.0]*n)
    
M[0][0],M[0][1],M[0][2],M[1][0],M[1][1],M[1][2],M[2][0],M[2][1],M[2][2]=8.0,2.0,-2.0,10.0,2.0,4.0,12.0,2.0,2.0 
b = [-2.0,4.0,6.0]
x = [0.0,0.0,0.0]
s = [0.0,0.0,0.0]
        
def eliminate(M,s,n,b,tol,er):
    for k in range(0,n):
        pivot(M,b,s,n,k)
        if (abs(M[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = M[i][k]/M[k][k]
            for j in range (k+1,n):
                M[i][j]=M[i][j]-factor*M[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(M[k][k]/s[k])<tol):
        er=-1
        
def pivot(M,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(M[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(M[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=M[p][j]
            M[p][j]=M[k][j]
            M[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(M,n,b,x):
    x[n-1]=b[n-1]/M[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*M[i][j]
        x[i]=(b[i]-suma)/M[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print ("X%d = %f" % (k,x[i]))
    
def gauss(M,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(M[i][1])
        for j in range(1,n):
            if (abs(M[i][j])>s[i]):
                s[i]=abs(M[i][j])
    eliminate(M,s,n,b,tol,er)
    if (er!=-1):
        substitute(M,n,b,x)


def Comprobar():

    x1,x2,x3 = x[0],x[1],x[2]
    f = round(8*x1+2*x2-2*x3)
    f2 = round(10*x1+2*x2+4*x3)
    f3 = round(12*x1+2*x2+2*x3)
    print ("\nComprobación: ")
    if (f==-2,f2==4,f3==6):
        return True
    else:
        return False
        
gauss(M,b,n,x,tol,er)

Comprobar()
# Out:
# X1 = 1.500000
# X2 = -6.500000
# X3 = 0.500000
#
# Comprobación:
# True

# %%
#Ejercicio 9.10

x=[0.0,1.0,5.0]
y=[-3.0,2.0,-2.0]
z=[7.0,-1.0,0.0]
i=[2.0,3.0,2.0]

def Solucionar(X,Y,Z):
    for i in range(3):
        if (i==0):
            d1=X[i]*Y[i+1]*Z[i+2]
            d2=X[i+2]*Y[i+1]*Z[i] 
        if (i==1):
            d1= d1+ (Y[i-1]*Z[i]*X[i+1])
            d2= d2+ (Y[i+1]*Z[i]*X[i-1])
        if (i==2):
            d1= d1+ (Y[i]*Z[i-2]*X[i-1])
            d2= d2+ (Y[i-2]*Z[i]*X[i-1])
    return d1-d2

det = Solucionar(x,y,z)
r1 = Solucionar(i,y,z)/det
r2 = Solucionar(x,i,z)/det
r3 = Solucionar(x,y,i)/det
print ("a) Determinante: ")
print (det)
print ("\nb) Soluciones: ")
print ("X1 = %f    X2 = %f    X3 = %f" % (r1,r2,r3))

n = 3
det = 1.0
m = []
for z in range(n):
    m.append([0.0]*n)
    
m[0][0],m[0][1],m[0][2],m[1][0],m[1][1],m[1][2],m[2][0],m[2][1],m[2][2]=0.0,-3.0,7.0,1.0,2.0,-1.0,5.0,-2.0,0.0 
b=[2.0,3.0,2.0]
x=[0.0,0.0,0.0]
s=[0.0,0.0,0.0]
        
def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(m,n,b,x):
    print ("\n")
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print ("X%d = %f"%(k,x[i]))
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)

def Comprobar():

    x1,x2,x3 = x[0],x[1],x[2]
    f = -3*x2+7*x3
    f2 = round(x1+2*x2-x3)
    f3 = round(5*x1-2*x2)
    print ("\nComprobación: ")
    if (f==2,f2==3,f3==2):
        return True
    else: 
        return False
        
gauss(m,b,n,x,tol,er)

Comprobar()
# Out:
# a) Determinante:
# -69.0
#
# b) Soluciones:
# X1 = 0.985507    X2 = 1.463768    X3 = 0.913043
#
#
# X1 = 0.985507
# X2 = 1.463768
# X3 = 0.913043
#
# Comprobación:
# True

# %%
#Ejercicio 9.11


n = 3
det = 1.0
m = []
for z in range(n):
    m.append([0.0]*n)
    
m[0][0],m[0][1],m[0][2],m[1][0],m[1][1],m[1][2],m[2][0],m[2][1],m[2][2]=2.0,-6.0,-1.0,-3.0,-1.0,7.0,-8.0,1.0,-2.0 
b=[-38.0,-34.0,-20.0]
x=[0.0,0.0,0.0]
s=[0.0,0.0,0.0]
        
def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print ("X%d = %f"%(k,x[i]))
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)

def Comprobar():

    x1,x2,x3 = x[0],x[1],x[2]
    f = round(2*x1-6*x2-x3)
    f2 = round(-3*x1-x2+7*x3)
    f3 = round(-8*x1+x2-2*x3)
    print ("\nComprobación: ")
    if (f==-38,f2==-34,f3==-20):
        return True
    else: 
        return False
        
gauss(m,b,n,x,tol,er)
Comprobar()
# Out:
# X1 = 4.000000
# X2 = 8.000000
# X3 = -2.000000
#
# Comprobación:
# True

# %%
#Ejercicio 9.12

k = 0
m = []
n = 3
for i in range(n):
    m.append([0.0]*(n+1))

m[0][0],m[0][1],m[0][2],m[0][3],m[1][0],m[1][1],m[1][2],m[1][3],m[2][0],m[2][1],m[2][2],m[2][3]=2.0,1,-1,1,5,2,2,-4,3,1,1,5

def div(m,k,n):
    temp=m[k][k]
    for y in range(n+1):
        m[k][y]=m[k][y]/temp
        
def Ceros(m,k,n):
    for x in range(n):
        if (x!=k):
            c = m[x][k]
            for z in range(n+1):
                m[x][z]=((-1*c)*m[k][z])+m[x][z]
                
for a in range(n):
    div(m,k,n)
    Ceros(m,k,n)
    k += 1
for x in range(0,n):
    print ("X%d = %f"%(x+1,m[x][n]))
    
def Comprobar():

    x1,x2,x3 = m[0][3],m[1][3],m[2][3]
    f = round(2*x1+x2-x3)
    f2 = round(5*x1+2*x2+2*x3)
    f3 = round(3*x1+x2+x3)
    print ("\nComprobación: ")
    if (f==1,f2==-4,f3==5):
        return True
    else:
        return False
        
Comprobar()
# Out:
# X1 = 14.000000
# X2 = -32.000000
# X3 = -5.000000
#
# Comprobación:
# True

# %%
#Ejercicio 9.13 a

for z in range(n):
    m.append([0.0]*n)
    
m[0][0],m[0][1],m[0][2],m[1][0],m[1][1],m[1][2],m[2][0],m[2][1],m[2][2]=1.0,1.0,-1.0,6.0,2.0,2.0,-3.0,4.0,1.0 
r = [-3.0,2.0,1.0]
x = [0.0,0.0,0.0]

def Sustitución():
    for i in range(n):
        for j in range(i,n):
            if (i==j):
                d = m[i][j]
                for s in range (n):
                    m[i][s]=((m[i][s])/d)
                r[i]=((r[i])/d)
            else:
                d=m[j][i]
                for p in range (n):
                    m[j][p]=m[j][p]-(d*m[i][p])
                r[j]=r[j]-(d*r[i])
def Eliminación():
    i=n-1
    j=n-1
    while (i>=0):
        y = r[i]
        while (j>=i):
            y=y-x[j]*m[i][j]
            j -= 1
        x[i]=y
        i -= 1
        j=n-1
    for i in range(n):
        k=i+1
        print ("\nX%d = %f"%(k,x[i]))
        
Sustitución()
Eliminación()
# Out:
# X1 = -0.250000
#
# X2 = -0.500000
#
# X3 = 2.250000

# %%
#Ejercicio 9.13 b

n = 3
det = 1.0

for z in range(n):
    m.append([0.0]*n)
    
m[0][0],m[0][1],m[0][2],m[1][0],m[1][1],m[1][2],m[2][0],m[2][1],m[2][2]=1.0,1.0,-1.0,6.0,2.0,2.0,-3.0,4.0,1.0 
b=[-3.0,2.0,1.0]
x=[0.0,0.0,0.0]
s=[0.0,0.0,0.0]
        
def eliminate(m,s,n,b,tol,er):
    for k in range(0,n):
        pivot(m,b,s,n,k)
        if (abs(m[k][k]/s[k])<tol):
            er=-1
        for i in range(k+1,n):
            factor = m[i][k]/m[k][k]
            for j in range (k+1,n):
                m[i][j]=m[i][j]-factor*m[k][j]
            b[i]=b[i]-factor*b[k]
    
    if (abs(m[k][k]/s[k])<tol):
        er=-1
        
def pivot(m,b,s,n,k):
    p,k=0,0
    p=k
    big = abs(m[k][k]/s[k])
    for i in range(k+1,n):
        dummy = abs(m[i][k]/s[i])
        if (dummy>big):
            big=dummy
            p=i
    if (p!=k):
        for j in range(k,n):
            dummy=m[p][j]
            m[p][j]=m[k][j]
            m[k][j]=dummy
        dummy=b[p]
        b[p]=b[k]
        b[k]=dummy
        dummy=s[p]
        s[p]=s[k]
        s[k]=dummy
    
def substitute(m,n,b,x):
    x[n-1]=b[n-1]/m[n-1][n-1]
    i=n-1
    while (i>=0):
        suma = 0
        for j in range(i+1,n):
            suma=suma+x[j]*m[i][j]
        x[i]=(b[i]-suma)/m[i][i]
        i -= 1
    for i in range(0,n):
        k=i+1
        print ("X%d = %f"%(k,x[i]))
    
def gauss(m,b,n,x,tol,er):
    for i in range(0,n):
        s[i]=abs(m[i][1])
        for j in range(1,n):
            if (abs(m[i][j])>s[i]):
                s[i]=abs(m[i][j])
    eliminate(m,s,n,b,tol,er)
    if (er!=-1):
        substitute(m,n,b,x)
        
gauss(m,b,n,x,tol,er)
# Out:
# X1 = -0.250000
# X2 = -0.500000
# X3 = 2.250000

# %%
#Ejercicio 9.13 c
n = 3
k = 0
m = []
for i in range(n):
    m.append([0.0]*(n+1))

m[0][0],m[0][1],m[0][2],m[0][3],m[1][0],m[1][1],m[1][2],m[1][3],m[2][0],m[2][1],m[2][2],m[2][3]=1.0,1,-1,-3,6,2,2,2,-3,4,1,1

def div(m,k,n):
    temp=0.0
    temp=m[k][k]
    for y in range(n+1):
        m[k][y]=m[k][y]/temp
        
def Ceros(m,k,n):
    for x in range(n):
        if (x!=k):
            c = m[x][k]
            for z in range(n+1):
                m[x][z]=((-1*c)*m[k][z])+m[x][z]
                
for a in range(n):
    div(m,k,n)
    Ceros(m,k,n)
    k += 1
for x in range(n):
    print ("X%d = %f"%(x+1,m[x][n]))
# Out:
# X1 = -0.250000
# X2 = -0.500000
# X3 = 2.250000
